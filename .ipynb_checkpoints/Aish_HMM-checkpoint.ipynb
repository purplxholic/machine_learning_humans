# %% [markdown]
# # Part 2.1

# %% [markdown]
# Reading training and parsing file

# %%
def read_file(file_path):
    file = open(file_path)
    parsed_file = []
    for line in file:
        if(line == ''): 
            break
        elif(line == '\n'):
            parsed_file.append((None, None))
            continue
        else: 
            temp = line.replace('\n','').split(' ')
            parsed_file.append(tuple(temp)) #return a tuple of word and its tag
      
    return parsed_file

# print(read_file("C:\\Users\\Lenovo\\Google Drive\\Courses\Term 6\\Machine Learning\\Project\\EN\\train"))
'''
returns something like this:
[('We', 'O'), ('were', 'O'), ('then', 'O'), ('charged', 'O'), ('for', 'O')......]
'''
# Out:
# "\nreturns something like this:\n[('We', 'O'), ('were', 'O'), ('then', 'O'), ('charged', 'O'), ('for', 'O')......]\n"

# %% [markdown]
# A helper function, smartify() is a function that takes file_path as input and returns training data in a 'smart' format.
# It returns a dictionary smart_data which is basically training data but in a smart format.
#
# Smart format is defined as: {tag:{word:frequency}}
# example: {'O': {'We': 83, 'were': 125, 'then': 15, 'charged': 2, 'for': 279}
#
# Also, smart_data.keys() (and also smartify().keys()) is list of all the tags

# %%
def smartify(file_path):
    training_data = read_file(file_path)
    smart_data = {} #smart_data is basically training data but in a smart format 
                    #smart format is {tag:{word:frequency}}
                    #example: {'O': {'We': 83, 'were': 125, 'then': 15, 'charged': 2, 'for': 279}
    for word_tag_pair in training_data:
        
        if word_tag_pair==(None,None): #annoying case -.-
            continue 
        
        #if tag not in smart_data yet, add it 
        if not word_tag_pair[1] in smart_data.keys():
            smart_data[word_tag_pair[1]]={}
        
        # if word not in smart_data[tag] yet, add it
        if not word_tag_pair[0] in smart_data[word_tag_pair[1]].keys():
            smart_data[word_tag_pair[1]][word_tag_pair[0]] = 0
        
        #increase frequency for each word-tag pair if seen
        smart_data[word_tag_pair[1]][word_tag_pair[0]] += 1
    return smart_data
    
# print (smartify("C:\\Users\\Lenovo\\Google Drive\\Courses\Term 6\\Machine Learning\\Project\\EN\\train"))

# %% [markdown]
# A function to modify training set

# %%
def modify_training_set(training_data, k):
    #input: smart_data
    count = 0 #not sure if we will need number of words replaced by unk, but lets keep count anyway
    
    training_data = training_data
    for tag, word in training_data.items():
        for specific_word, f in list(word.items()):
            if (f<k):
                count +=f
#                 print(specific_word,f)
                #replace with #unk#
                word.pop(specific_word)
        word["#UNK#"] = count

    return training_data
# modify_training_set(smartify("C:\\Users\\Lenovo\\Google Drive\\Courses\Term 6\\Machine Learning\\Project\\EN\\train"),3)
# Out:
# {'B-negative': {'#UNK#': 3722,
#   'Service': 8,
#   'Thai': 3,
#   'customer': 4,
#   'dessert': 5,
#   'dishes': 4,
#   'fish': 6,
#   'food': 41,
#   'management': 3,
#   'manager': 8,
#   'meal': 4,
#   'meals': 3,
#   'menu': 4,
#   'pizza': 4,
#   'place': 24,
#   'portions': 3,
#   'restaurant': 12,
#   'service': 36,
#   'staff': 13,
#   'sushi': 4,
#   'waiter': 8,
#   'waitress': 10},
#  'B-neutral': {'#UNK#': 3054, 'Food': 5, 'decor': 4, 'food': 10},
#  'B-positive': {'#UNK#': 3547,
#   'Atmosphere': 3,
#   'Food': 9,
#   'Grilled': 3,
#   'Indian': 5,
#   'Mizu': 3,
#   'PLACE': 3,
#   'Pizza': 7,
#   'Service': 9,
#   'Suan': 3,
#   'Sushi': 7,
#   'Thai': 4,
#   'ambiance': 7,
#   'ambience': 7,
#   'appetizer': 4,
#   'atmosphere': 22,
#   'back': 3,
#   'bagels': 5,
#   'bar': 4,
#   'breakfast': 3,
#   'chicken': 9,
#   'crab': 4,
#   'crust': 3,
#   'decor': 12,
#   'dishes': 5,
#   'drinks': 10,
#   'filet': 5,
#   'fish': 11,
#   'food': 126,
#   'fried': 3,
#   'hot': 5,
#   'indian': 3,
#   'ingredients': 3,
#   'lobster': 4,
#   'location': 3,
#   'main': 3,
#   'margherita': 3,
#   'meal': 15,
#   'menu': 12,
#   'music': 8,
#   'outdoor': 4,
#   'owner': 3,
#   'pancakes': 3,
#   'people': 5,
#   'pizza': 21,
#   'place': 65,
#   'portions': 5,
#   'restaurant': 27,
#   'rolls': 7,
#   'sake': 7,
#   'seafood': 6,
#   'selection': 3,
#   'server': 5,
#   'servers': 3,
#   'service': 79,
#   'setting': 4,
#   'specials': 4,
#   'spicy': 3,
#   'spot': 7,
#   'staff': 23,
#   'sushi': 15,
#   'toppings': 3,
#   'veal': 3,
#   'vibe': 4,
#   'view': 6,
#   'wait': 5,
#   'waiter': 8,
#   'waiters': 6,
#   'waitstaff': 4,
#   'wine': 19},
#  'I-negative': {'#UNK#': 3835,
#   'and': 4,
#   'of': 4,
#   'service': 5,
#   'staff': 4,
#   'the': 3},
#  'I-neutral': {'#UNK#': 4218},
#  'I-positive': {'#UNK#': 4195,
#   '(': 6,
#   ')': 6,
#   ',': 5,
#   'Thai': 3,
#   'and': 16,
#   'appetizer': 4,
#   'atmosphere': 3,
#   'brulee': 3,
#   'cheese': 4,
#   'chicken': 3,
#   'clams': 3,
#   'creme': 3,
#   'dessert': 3,
#   'dish': 3,
#   'dishes': 5,
#   'dog': 3,
#   'dumplings': 3,
#   'fish': 4,
#   'food': 20,
#   'list': 13,
#   'menu': 8,
#   'mignon': 3,
#   'of': 13,
#   'on': 3,
#   'pizza': 11,
#   'place': 6,
#   'prawns': 3,
#   'restaurant': 4,
#   'roll': 10,
#   'rolls': 3,
#   'room': 3,
#   'salad': 5,
#   'sandwich': 3,
#   'sauce': 3,
#   'selection': 5,
#   'shrimp': 4,
#   'soup': 4,
#   'special': 9,
#   'spot': 3,
#   'staff': 4,
#   'style': 3,
#   'tea': 4,
#   'tempura': 3,
#   'the': 4,
#   'wine': 5,
#   'with': 8},
#  'O': {'!': 270,
#   '"': 41,
#   '#UNK#': 3008,
#   '$': 46,
#   '%': 4,
#   '&': 9,
#   "'": 16,
#   '(': 80,
#   ')': 83,
#   '+': 4,
#   ',': 943,
#   '-': 85,
#   '.': 1524,
#   '..': 12,
#   '...': 87,
#   '/': 12,
#   '1': 7,
#   '10': 6,
#   '100': 3,
#   '15': 5,
#   '1st': 3,
#   '2': 16,
#   '20': 6,
#   '2nd': 3,
#   '3': 12,
#   '30': 4,
#   '35': 3,
#   '4': 3,
#   '5': 9,
#   '500': 3,
#   '6': 4,
#   '7': 3,
#   '8': 5,
#   ':': 25,
#   ':)': 6,
#   ';': 16,
#   '?': 32,
#   'A': 25,
#   'AMAZING': 3,
#   'After': 8,
#   'All': 9,
#   'Also': 8,
#   'Although': 3,
#   'Always': 5,
#   'And': 13,
#   'As': 6,
#   'At': 4,
#   'Authentic': 3,
#   'BEST': 5,
#   'Be': 4,
#   'Best': 17,
#   'Brooklyn': 6,
#   'But': 13,
#   'By': 4,
#   "Can't": 3,
#   'Chinese': 3,
#   'City': 6,
#   'Definitely': 4,
#   'Delicious': 3,
#   'Disney': 3,
#   'Dokebi': 3,
#   "Don't": 7,
#   'Even': 3,
#   'Every': 4,
#   'Everyone': 3,
#   'Everything': 9,
#   'Excellent': 6,
#   'Farm': 3,
#   'Finally': 3,
#   'First': 4,
#   'Flatbush': 3,
#   'For': 12,
#   'Friday': 3,
#   'Go': 9,
#   'Good': 9,
#   'Great': 30,
#   'Had': 4,
#   'Have': 5,
#   'He': 3,
#   'Highly': 5,
#   'How': 4,
#   'However': 10,
#   'I': 473,
#   "I'd": 7,
#   "I'll": 6,
#   "I'm": 18,
#   "I've": 36,
#   'IT': 4,
#   'If': 23,
#   'In': 9,
#   'Indian': 9,
#   'It': 31,
#   "It's": 18,
#   'Italian': 7,
#   'Its': 3,
#   'Ive': 4,
#   'Japanese': 8,
#   'Just': 9,
#   'Kobe': 3,
#   'Korean': 3,
#   'L': 3,
#   'La': 3,
#   'Love': 7,
#   'Loved': 3,
#   'Manhattan': 9,
#   'Maybe': 4,
#   'Most': 4,
#   'My': 35,
#   'NEVER': 4,
#   'NO': 3,
#   'NOT': 5,
#   'NY': 10,
#   'NYC': 14,
#   'Never': 3,
#   'New': 14,
#   'Nice': 5,
#   'No': 6,
#   'Not': 17,
#   'OK': 3,
#   'Oh': 4,
#   'On': 4,
#   'Once': 3,
#   'One': 7,
#   'Our': 13,
#   'Over': 3,
#   'Overall': 5,
#   'Overpriced': 3,
#   'Park': 3,
#   'Poor': 3,
#   'Price': 4,
#   'Prices': 3,
#   "Ray's": 4,
#   'Saturday': 4,
#   'Save': 3,
#   'Sea': 3,
#   'Seattle': 5,
#   'She': 4,
#   'So': 9,
#   'St': 4,
#   'Street': 4,
#   'Sunday': 5,
#   'THE': 8,
#   'THIS': 3,
#   'Taiwanese': 3,
#   'Thai': 8,
#   'The': 303,
#   'Their': 7,
#   'There': 11,
#   'They': 26,
#   'This': 50,
#   'To': 6,
#   'Too': 4,
#   'Toons': 3,
#   'Try': 8,
#   'Very': 7,
#   'Village': 6,
#   'WAS': 3,
#   'We': 83,
#   "We've": 3,
#   'Well': 3,
#   'Went': 7,
#   'West': 3,
#   'What': 10,
#   'When': 11,
#   'While': 7,
#   'Will': 4,
#   'With': 4,
#   'Yes': 3,
#   'York': 11,
#   'You': 19,
#   'a': 537,
#   'able': 3,
#   'about': 53,
#   'above': 6,
#   'absolutely': 12,
#   'accomodating': 5,
#   'across': 6,
#   'actually': 10,
#   'add': 3,
#   'after': 17,
#   'afternoon': 4,
#   'again': 26,
#   'ahead': 4,
#   'all': 85,
#   'almost': 7,
#   'alone': 5,
#   'alot': 3,
#   'already': 4,
#   'alright': 3,
#   'also': 20,
#   'although': 7,
#   'always': 31,
#   'am': 18,
#   'amazing': 25,
#   'an': 64,
#   'and': 765,
#   'anniversary': 3,
#   'another': 9,
#   'any': 19,
#   'anyone': 4,
#   'anything': 7,
#   'anywhere': 3,
#   'apart': 3,
#   'apology': 4,
#   'appetizer': 4,
#   'appetizers': 6,
#   'appetizing': 4,
#   'are': 131,
#   'area': 9,
#   'around': 19,
#   'arrived': 7,
#   'arrogant': 3,
#   'as': 67,
#   'ask': 12,
#   'asked': 14,
#   'asking': 3,
#   'at': 110,
#   'ate': 9,
#   'attention': 3,
#   'attentive': 18,
#   'attitude': 6,
#   'authentic': 6,
#   'average': 18,
#   'away': 15,
#   'awesome': 11,
#   'back': 65,
#   'bad': 20,
#   'bagel': 5,
#   'bar': 8,
#   'barely': 3,
#   'be': 100,
#   'beat': 3,
#   'beautiful': 9,
#   'became': 3,
#   'because': 23,
#   'beef': 3,
#   'been': 55,
#   'before': 17,
#   'begin': 5,
#   'being': 18,
#   'believe': 9,
#   'belly': 3,
#   'best': 62,
#   'better': 25,
#   'between': 3,
#   'big': 17,
#   'bigger': 3,
#   'bill': 12,
#   'birthday': 12,
#   'bit': 19,
#   'bite': 9,
#   'bland': 10,
#   'blocks': 3,
#   'both': 15,
#   'boyfriend': 11,
#   'breakfast': 3,
#   'bring': 4,
#   'brought': 4,
#   'brunch': 3,
#   'business': 5,
#   'busy': 5,
#   'but': 188,
#   'by': 59,
#   'called': 7,
#   'came': 28,
#   'can': 46,
#   "can't": 30,
#   'cannot': 4,
#   'casual': 7,
#   'cause': 3,
#   'celebrate': 3,
#   'certainly': 5,
#   'chance': 3,
#   'charge': 3,
#   'charming': 4,
#   'cheap': 11,
#   'check': 15,
#   'cheese': 6,
#   'chicken': 6,
#   'choice': 4,
#   'choices': 3,
#   'city': 10,
#   'clean': 6,
#   'close': 5,
#   'cold': 12,
#   'come': 16,
#   'comes': 5,
#   'coming': 10,
#   'comment': 5,
#   'complained': 3,
#   'completely': 7,
#   'consider': 5,
#   'considering': 3,
#   'consistent': 4,
#   'conversation': 5,
#   'cooked': 8,
#   'cool': 5,
#   'corner': 3,
#   'cost': 5,
#   'could': 16,
#   'couple': 8,
#   'course': 5,
#   'cozy': 8,
#   'creative': 6,
#   'crowd': 5,
#   'crowded': 7,
#   'crust': 3,
#   'customers': 7,
#   'cut': 3,
#   'cute': 3,
#   'daring': 3,
#   'date': 13,
#   'day': 13,
#   'deal': 7,
#   'decent': 7,
#   'decide': 3,
#   'decided': 6,
#   'definitely': 12,
#   'delicious': 53,
#   'delivered': 4,
#   'describe': 3,
#   'dessert': 5,
#   'desserts': 3,
#   'did': 21,
#   "didn't": 20,
#   'die': 7,
#   'different': 15,
#   'dine': 9,
#   'dining': 11,
#   'dinner': 33,
#   'dinning': 3,
#   'disappointed': 11,
#   'disappointment': 4,
#   'discount': 3,
#   'disgusting': 3,
#   'dish': 6,
#   'dishes': 7,
#   'do': 21,
#   'does': 5,
#   "doesn't": 8,
#   "don't": 41,
#   'done': 6,
#   'dont': 6,
#   'down': 17,
#   'drawback': 3,
#   'dress': 3,
#   'drink': 6,
#   'drinks': 11,
#   'drive': 4,
#   'dry': 4,
#   'during': 4,
#   'each': 8,
#   'early': 3,
#   'east': 4,
#   'eat': 29,
#   'eaten': 14,
#   'eater': 3,
#   'eating': 11,
#   'either': 8,
#   'else': 10,
#   'empty': 5,
#   'end': 4,
#   'enjoy': 20,
#   'enjoyed': 6,
#   'enjoying': 3,
#   'enormous': 3,
#   'enough': 16,
#   'entertainment': 3,
#   'entire': 4,
#   'entree': 3,
#   'especially': 9,
#   'establishment': 3,
#   'etc': 5,
#   'even': 35,
#   'evening': 10,
#   'event': 3,
#   'ever': 24,
#   'every': 23,
#   'everyone': 9,
#   'everything': 15,
#   'exactly': 3,
#   'excellent': 27,
#   'except': 4,
#   'exceptional': 6,
#   'excited': 3,
#   'excuse': 3,
#   'expect': 5,
#   'expectations': 3,
#   'expected': 4,
#   'expensive': 13,
#   'experience': 29,
#   'experienced': 3,
#   'extensive': 8,
#   'extra': 4,
#   'extremely': 9,
#   'fabulous': 4,
#   'face': 3,
#   'fact': 9,
#   'fairly': 4,
#   'family': 9,
#   'fantastic': 12,
#   'far': 16,
#   'fast': 13,
#   'favorite': 15,
#   'feel': 19,
#   'feeling': 7,
#   'felt': 6,
#   'few': 13,
#   'finally': 12,
#   'find': 17,
#   'fine': 10,
#   'first': 17,
#   'fish': 6,
#   'five': 3,
#   'flavor': 7,
#   'floor': 4,
#   'folks': 3,
#   'food': 51,
#   'for': 279,
#   'forget': 4,
#   'forgotten': 3,
#   'found': 15,
#   'four': 6,
#   'free': 3,
#   'fresh': 24,
#   'freshest': 3,
#   'friend': 15,
#   'friendly': 29,
#   'friends': 18,
#   'from': 50,
#   'front': 5,
#   'frozen': 3,
#   'full': 6,
#   'fun': 15,
#   'further': 3,
#   'gem': 8,
#   'generally': 3,
#   'get': 49,
#   'gets': 8,
#   'getting': 8,
#   'girlfriend': 3,
#   'girls': 3,
#   'give': 11,
#   'given': 3,
#   'glass': 6,
#   'glasses': 3,
#   'go': 78,
#   'going': 25,
#   'gone': 5,
#   'good': 158,
#   'got': 20,
#   'great': 139,
#   'greatest': 4,
#   'group': 4,
#   'guess': 5,
#   'guests': 4,
#   'guy': 3,
#   'guys': 3,
#   'had': 126,
#   'half': 9,
#   'hand': 4,
#   'hands': 3,
#   'hang': 4,
#   'happens': 4,
#   'happy': 7,
#   'hard': 5,
#   'has': 35,
#   'hate': 3,
#   'have': 148,
#   'having': 4,
#   'he': 13,
#   'hear': 3,
#   'heard': 3,
#   'helpful': 7,
#   'her': 9,
#   'here': 69,
#   'high': 10,
#   'highly': 20,
#   'him': 3,
#   'his': 7,
#   'holiday': 3,
#   'home': 7,
#   'honestly': 3,
#   'hope': 3,
#   'horrible': 10,
#   'hot': 11,
#   'hour': 10,
#   'how': 12,
#   'however': 9,
#   'huge': 11,
#   'hungry': 3,
#   'husband': 10,
#   'i': 45,
#   "i've": 3,
#   'idea': 4,
#   'if': 51,
#   'ignore': 3,
#   'impressed': 7,
#   'impressive': 3,
#   'in': 256,
#   'included': 4,
#   'including': 8,
#   'incredible': 8,
#   'indian': 3,
#   'inedible': 3,
#   'inexpensive': 3,
#   'innovative': 3,
#   'inside': 5,
#   'instead': 6,
#   'interesting': 5,
#   'intimate': 6,
#   'into': 13,
#   'inventive': 3,
#   'is': 462,
#   'it': 252,
#   "it's": 30,
#   'its': 16,
#   'itself': 3,
#   'joint': 3,
#   'just': 60,
#   'keep': 11,
#   'kept': 3,
#   'kind': 4,
#   'know': 16,
#   'lacking': 4,
#   'large': 8,
#   'last': 21,
#   'late': 10,
#   'later': 3,
#   'least': 12,
#   'leave': 4,
#   'left': 13,
#   'less': 6,
#   'level': 3,
#   'light': 3,
#   'like': 60,
#   'liked': 5,
#   'likely': 4,
#   'line': 3,
#   'list': 5,
#   'listed': 5,
#   'little': 25,
#   'live': 7,
#   'lived': 6,
#   'local': 3,
#   'located': 5,
#   'location': 4,
#   'long': 8,
#   'look': 6,
#   'looked': 7,
#   'looking': 11,
#   'looks': 3,
#   'lot': 15,
#   'loud': 3,
#   'lousy': 3,
#   'love': 23,
#   'loved': 7,
#   'lovely': 4,
#   'lovers': 3,
#   'lunch': 12,
#   'made': 28,
#   'maggot': 3,
#   'make': 24,
#   'makes': 5,
#   'manager': 6,
#   'many': 25,
#   'matter': 5,
#   'may': 13,
#   'maybe': 4,
#   'me': 43,
#   'meal': 6,
#   'mean': 6,
#   'means': 4,
#   'meat': 6,
#   'mediocre': 6,
#   'mention': 5,
#   'menu': 15,
#   'mess': 3,
#   'mid': 4,
#   'might': 7,
#   'mind': 7,
#   'minutes': 21,
#   'miss': 4,
#   'money': 12,
#   'month': 3,
#   'months': 3,
#   'more': 55,
#   'most': 26,
#   'mouth': 4,
#   'much': 26,
#   'music': 4,
#   'must': 13,
#   'my': 117,
#   'myself': 7,
#   'name': 6,
#   'nearby': 4,
#   'nearly': 3,
#   'need': 7,
#   'needs': 6,
#   'neighborhood': 11,
#   'never': 42,
#   'new': 8,
#   'next': 15,
#   'nice': 43,
#   'night': 28,
#   'nights': 4,
#   'no': 41,
#   'not': 157,
#   'notch': 4,
#   'nothing': 17,
#   'now': 11,
#   'occasion': 5,
#   'of': 296,
#   'off': 17,
#   'offer': 4,
#   'offered': 5,
#   'offers': 4,
#   'often': 10,
#   'oily': 8,
#   'ok': 12,
#   'okay': 7,
#   'old': 5,
#   'on': 146,
#   'once': 20,
#   'one': 66,
#   'only': 39,
#   'open': 4,
#   'or': 63,
#   'order': 26,
#   'ordered': 26,
#   'ordering': 3,
#   'other': 27,
#   'our': 50,
#   'out': 58,
#   'outside': 6,
#   'outstanding': 6,
#   'over': 28,
#   'overall': 3,
#   'overpriced': 9,
#   'own': 3,
#   'oz': 3,
#   'packed': 5,
#   'paid': 6,
#   'part': 9,
#   'particularly': 4,
#   'party': 10,
#   'past': 5,
#   'pay': 8,
#   'people': 18,
#   'per': 5,
#   'perfect': 15,
#   'person': 8,
#   'phenomenal': 3,
#   'picked': 3,
#   'piece': 8,
#   'pizza': 9,
#   'place': 66,
#   'places': 25,
#   'planning': 4,
#   'plate': 4,
#   'plates': 5,
#   'playing': 3,
#   'pleasant': 7,
#   'pleasantly': 7,
#   'please': 3,
#   'point': 5,
#   'poor': 8,
#   'popular': 3,
#   'positive': 3,
#   'possible': 3,
#   'prepared': 9,
#   'presentation': 3,
#   'pretty': 20,
#   'previous': 3,
#   'price': 28,
#   'priced': 9,
#   'prices': 24,
#   'pricey': 7,
#   'private': 3,
#   'probably': 10,
#   'problem': 7,
#   'prompt': 4,
#   'put': 3,
#   'quality': 19,
#   'quantity': 3,
#   'quick': 4,
#   'quickly': 5,
#   'quiet': 4,
#   'quite': 12,
#   'rather': 7,
#   're': 3,
#   'real': 8,
#   'really': 44,
#   'reason': 4,
#   'reasonable': 9,
#   'reasonably': 6,
#   'received': 6,
#   'recently': 4,
#   'recommend': 30,
#   'recommended': 9,
#   'refreshing': 3,
#   'relaxed': 4,
#   'relaxing': 3,
#   'remember': 8,
#   'replied': 4,
#   'reputation': 3,
#   'requested': 3,
#   'reservation': 7,
#   'reservations': 4,
#   'restaurant': 61,
#   'restaurants': 24,
#   'return': 12,
#   'review': 6,
#   'reviews': 10,
#   'rice': 8,
#   'right': 8,
#   'roll': 4,
#   'romantic': 10,
#   'room': 7,
#   'rude': 15,
#   'run': 3,
#   's': 5,
#   'said': 12,
#   'sake': 6,
#   'salmon': 4,
#   'same': 10,
#   'sandwich': 4,
#   'sat': 10,
#   'saturday': 3,
#   'sauce': 3,
#   'saw': 4,
#   'say': 26,
#   'says': 4,
#   'seat': 6,
#   'seated': 14,
#   'second': 4,
#   'see': 10,
#   'seem': 4,
#   'seemed': 4,
#   'seems': 3,
#   'seen': 5,
#   'selection': 5,
#   'sense': 3,
#   'serve': 8,
#   'served': 14,
#   'service': 12,
#   'serving': 3,
#   'several': 9,
#   'share': 6,
#   'shared': 4,
#   'she': 19,
#   'should': 13,
#   'side': 14,
#   'simple': 4,
#   'simply': 10,
#   'since': 16,
#   'sister': 3,
#   'sit': 4,
#   'sitting': 7,
#   'size': 7,
#   'skip': 3,
#   'slightly': 4,
#   'slow': 7,
#   'small': 19,
#   'smile': 3,
#   'so': 110,
#   'soggy': 3,
#   'some': 29,
#   'someone': 6,
#   'something': 5,
#   'sometimes': 8,
#   'son': 3,
#   'soon': 4,
#   'sooo': 3,
#   'special': 14,
#   'spectacular': 5,
#   'spend': 3,
#   'spent': 4,
#   'spicy': 4,
#   'spot': 4,
#   'stairs': 3,
#   'start': 4,
#   'stay': 3,
#   'still': 11,
#   'stomach': 4,
#   'stop': 5,
#   'stopped': 3,
#   'street': 7,
#   'stuff': 3,
#   'such': 19,
#   'summer': 3,
#   'super': 3,
#   'superb': 3,
#   'sure': 19,
#   'surprised': 5,
#   'survives': 3,
#   'sushi': 15,
#   'sweet': 6,
#   't': 8,
#   'table': 33,
#   'tables': 3,
#   'take': 15,
#   'taken': 3,
#   'taste': 12,
#   'tasted': 14,
#   'tasty': 23,
#   'tell': 5,
#   'terrific': 4,
#   'than': 38,
#   'that': 179,
#   "that's": 11,
#   'the': 1101,
#   'their': 52,
#   'them': 15,
#   'then': 15,
#   'there': 95,
#   "there's": 4,
#   'these': 7,
#   'they': 82,
#   "they're": 3,
#   'thin': 5,
#   'thing': 19,
#   'things': 8,
#   'think': 13,
#   'this': 142,
#   'those': 8,
#   'though': 22,
#   'thought': 13,
#   'three': 6,
#   'through': 9,
#   'time': 64,
#   'times': 24,
#   'tiny': 6,
#   'tip': 5,
#   'to': 477,
#   'together': 5,
#   'toilet': 3,
#   'told': 8,
#   'tons': 3,
#   'too': 51,
#   'took': 17,
#   'top': 17,
#   'totally': 4,
#   'town': 12,
#   'traditional': 4,
#   'treated': 3,
#   'tried': 12,
#   'trip': 10,
#   'true': 3,
#   'trust': 3,
#   'try': 28,
#   'trying': 9,
#   'twice': 4,
#   'two': 14,
#   'type': 3,
#   'um': 3,
#   'unique': 4,
#   'unless': 3,
#   'unpleasant': 3,
#   'up': 36,
#   'upon': 5,
#   'us': 39,
#   'use': 5,
#   'used': 5,
#   'usually': 7,
#   'value': 7,
#   'variety': 6,
#   'very': 103,
#   'village': 4,
#   'visit': 19,
#   'visited': 5,
#   'visiting': 3,
#   'wait': 31,
#   'waited': 8,
#   'waiting': 9,
#   'waitress': 4,
#   'walk': 4,
#   'walked': 9,
#   'walking': 3,
#   'want': 20,
#   'wanted': 10,
#   'warm': 13,
#   'was': 424,
#   "wasn't": 15,
#   'waste': 5,
#   'watching': 3,
#   'water': 8,
#   'way': 21,
#   'we': 133,
#   "we've": 9,
#   'weather': 4,
#   'week': 7,
#   'weekends': 5,
#   'weird': 3,
#   'well': 34,
#   'went': 27,
#   'were': 125,
#   "weren't": 4,
#   'west': 4,
#   'what': 37,
#   'when': 41,
#   'where': 10,
#   'which': 64,
#   'while': 15,
#   'who': 23,
#   'wife': 12,
#   'will': 38,
#   'wine': 10,
#   'wish': 4,
#   'with': 130,
#   'without': 14,
#   "won't": 7,
#   'wonderful': 15,
#   'work': 8,
#   'world': 13,
#   'worst': 8,
#   'worth': 31,
#   'would': 55,
#   "wouldn't": 5,
#   'write': 3,
#   'wrong': 9,
#   'year': 6,
#   'years': 18,
#   'yes': 4,
#   'yet': 8,
#   'you': 180,
#   "you're": 15,
#   'young': 3,
#   'your': 51,
#   'yourself': 8,
#   'yummy': 5,
#   'â€“': 58,
#   'â€™': 14}}

# %% [markdown]
# A function to estimate emission parameters

# %%
import math
def emission(file_path):
    emissions = {}
    training_data = smartify(file_path)
    training_data = modify_training_set(training_data, k=3) #modify training data 
    
    for tag, word in training_data.items():
        
        count_y = sum(word.values())
#         print (count_y)
'O'): 0.019676594340400956, ('wait', 'O'): 0.0012787723785166241, ('everything', 'O'): 0.0006187608283144955, ('ask', 'O'): 0.0004950086626515964, ('several', 'O'): 0.0003712564969886973, ('different', 'O'): 0.0006187608283144955, ('people', 'O'): 0.0007425129939773946, ('same', 'O'): 0.00041250721887633036, ('thing', 'O'): 0.0007837637158650277, ('before', 'O'): 0.0007012622720897616, ('be', 'O'): 0.004125072188763303, ('served', 'O'): 0.0005775101064268625, ('This', 'O'): 0.0020625360943816516, ('great', 'O'): 0.005733850342380992, ('place', 'O'): 0.00272254764458378, ('get', 'O'): 0.0020212853724940185, ('so', 'O'): 0.004537579407639634, ('now', 'O'): 0.00045375794076396337, ('what', 'O'): 0.0015262767098424223, ('are', 'O'): 0.0054038445672799276, ('appetizers', 'O'): 0.0002475043313257982, ('?', 'O'): 0.001320023100404257, ('I', 'O'): 0.019511591452850426, ('dining', 'O'): 0.00045375794076396337, ('at', 'O'): 0.004537579407639634, ('like', 'O'): 0.002475043313257982, ('no', 'O'): 0.0016912795973929543, ('other', 'O'): 0.001113769490966092, ('experience', 'O'): 0.001196270934741358, ('It', 'O'): 0.0012787723785166241, ("wasn't", 'O'): 0.0006187608283144955, ('freshest', 'O'): 0.0001237521656628991, ('ever', 'O'): 0.0009900173253031927, ('taste', 'O'): 0.0004950086626515964, ('presentation', 'O'): 0.0001237521656628991, ('OK', 'O'): 0.000123752 ...

# %% [markdown]
# A function for reading test file

# %%
def read_test_file(file_path):
    file = open(file_path)
    parsed_file = []
    for line in file:
        if(line == ''):
            break
        if(line == '\n'):
            parsed_file.append(None)
            continue
        parsed_file.append(line.replace('\n',''))
    return parsed_file

# print(read_test_file("C:\\Users\\Lenovo\\Google Drive\\Courses\\Term 6\Machine Learning\\Project\\EN\\dev.in"))

# %% [markdown]
# A function to clean up the train file (replace words not in training set with '#UNK#')

# %%
def clean_up_test_data(test_data, emissions_dict):
    
    test_data = test_data
#     print("Original test data:",len(test_data))
    
    training_data = []
    list_of_replaced_words = []
    for tup in emissions_dict.keys():
        training_data.append(tup[0])
#     print(training_data)
    #compare training and test data and replace non-common words with #UNK#
    for word in test_data:
        if word =='START' or word=='STOP':
            continue
        elif word not in training_data:
            list_of_replaced_words.append(word) #we might need this for testing if the function is working
            index = test_data.index(word)
            test_data[index] = "#UNK#"
            
#     print("Number of replaced words:",len(list_of_replaced_words))        
#     print("Cleaned up test data:",len(test_data))

    return test_data
# print (clean_up_test_data( read_test_file("C:\\Users\\Lenovo\\Google Drive\\Courses\\Term 6\Machine Learning\\Project\\EN\\dev.in"),emission("C:\\Users\\Lenovo\\Google Drive\\Courses\Term 6\\Machine Learning\\Project\\EN\\train")))

# %% [markdown]
# Simple sentiment analysis function that computes argmax

# %%
def sentiment_anal(train_file_path, test_file_path):
    test_data = read_test_file(test_file_path)
    emissions = emission(train_file_path)
    cleaned_up_test_data = clean_up_test_data(test_data,emissions)
    
#     print(cleaned_up_test_data)
    argmax = []
    for word in cleaned_up_test_data:
#         print(word)
        if word == None:
            argmax.append((None, None))
            continue
        temp = {}
        
        #filter out common words into temp 
        for key in emissions.keys():

            if(key[0] == word):
#                 print(emissions[key])
                temp[key] = emissions[key]
                

        if temp=={}:
            continue
        else:
            result = max(temp, key=temp.get)
#             print(result)
        argmax.append(result)
#     print (temp)
#     print (argmax)
    return argmax


# sentiment_anal("C:\\Users\\Lenovo\\Google Drive\\Courses\Term 6\\Machine Learning\\Project\\EN\\train" ,"C:\\Users\\Lenovo\\Google Drive\\Courses\\Term 6\Machine Learning\\Project\\EN\\dev.in")

# %% [markdown]
# Write into dev.pn.out

# %%
def write_dev_out(input_data):
    path = "C:\\Users\\Lenovo\\Google Drive\\Courses\\Term 6\\Machine Learning\\Project\EN\\"
    filename = "dev.p2.out"
    with open(path+filename, 'w') as f:
        for tup in input_data:
            f.write(tup[0] + ' ' + tup[1]+'\n')
    f.close()

# write_dev_out(sentiment_anal("C:\\Users\\Lenovo\\Google Drive\\Courses\Term 6\\Machine Learning\\Project\\EN\\train" ,"C:\\Users\\Lenovo\\Google Drive\\Courses\\Term 6\Machine Learning\\Project\\EN\\dev.in"))

# %% [markdown]
# # Part 3

# %% [markdown]
# Function to take training data as input

# %%
def prepare_input_data_for_transition_paramaters(file_path):
    input_data = (read_file(file_path))
    input_data = [("START",None)]+input_data
    
    #wherever (None, None) is seen, instert a STOP and START
    for tup in input_data:
        if (tup == (None,None)):
            index = input_data.index(tup)
            #add a stop
            input_data[index] = ("STOP",None)
            input_data = input_data[:index+1] + [("START", None)]+ input_data[index+1:]
            
    #take care of the ending of the file
    input_data.pop(-2)
    return input_data 
    
    
# prepare_input_data_for_transition_paramaters("C:\\Users\\Lenovo\\Google Drive\\Courses\Term 6\\Machine Learning\\Project\\EN\\train")

# %% [raw]
# Function to estimate transition paramaters

# %%
def estimate_transition_parameters(file_path):
    input_data = prepare_input_data_for_transition_paramaters(file_path)
    
    emission_pairs = {}
    yi_1_count = {}
    
    
    for i in range (len(input_data)-1):
        yi_1 = input_data[i][1]
        yi = input_data[i+1][1]
        
        temp_tup = (yi_1,yi)
        if not temp_tup in emission_pairs.keys():
            emission_pairs[temp_tup] = 1
        else:
            emission_pairs[temp_tup]+=1
        
        if not yi_1 in yi_1_count.keys():
            yi_1_count[yi_1] = 1
        else: 
            yi_1_count[yi_1] += 1
            
            
#     print (emission_pairs)
#     print (yi_1_count)

    transition_params = emission_pairs #this is just for convenience
    
    for yi_1, count in yi_1_count.items():
        
        for tup in emission_pairs.keys():
            if (tup[0]==yi_1):
                transition_params[tup] = float(emission_pairs[tup]/count)
    
#     print(transition_params)
    return(transition_params)

    
    
    
            
    
# estimate_transition_parameters("C:\\Users\\Lenovo\\Google Drive\\Courses\Term 6\\Machine Learning\\Project\\EN\\train")

# %%
def construct_sentences(file_path):
    file = open(file_path)
    sentences = []
    sentence = ['START']
    for line in file:
        if(line == ''):
            break
        if(line == '\n'):
            sentence.append('STOP')
            sentences.append(sentence)
            sentence = ['START']
            continue
        else:
            sentence.append(line.replace('\n',''))
            
    return sentences 

# print(construct_sentences("C:\\Users\\Lenovo\\Google Drive\\Courses\\Term 6\Machine Learning\\Project\\EN\\dev.in"))

# %%
# import math
# def viterbi(train_file_path, test_file_path):
    
#     tags = ['O','B-positive','B-neutral','B-negative','I-positive','I-negative','I-neutral']
#     emission_p = emission(train_file_path) #{('We', 'O'): 0.003423668687868663, ('were', 'O'): 0.005156127541970878, ('then', 'O'): 0.0006187353050365054,}
# #     print("Emission p:",emission_p,"\n")
#     transition_p = estimate_transition_parameters(train_file_path) #{(None, 'O'): 0.47022696929238983, ('O', 'O'): 0.8601188020790363, ('O', None): 0.07623133404834585,}
# #     print("Transition p:",transition_p,"\n")
#     sentences = construct_sentences(test_file_path)

#     for i in range(len(sentences)):
#         sentences[i]=clean_up_test_data(sentences[i],emission_p)
    
#     for sentence in sentences:
#         sentence = sentences[2]
#         print(sentence)
#         dp_table = [{},{}]
#         for tag in tags:
#             if((None,tag) in transition_p.keys()):
                
#                 a_i_j = transition_p[(None,tag)] #transition probability from 'START'to tag

#             else:
#                 a_i_j = 0
                            
#             if( (sentence[1],tag) in emission_p.keys()):
                
#                 b_j = emission_p[(sentence[1],tag)] #probability that tag emits word
                            
#             else:
#                 b_j = 0
                           
            
# #             print(sentence[1],tag,"a_i_j=",a_i_j,"b_j=",b_j)
#             dp_table[1][tag] = {'p': a_i_j*b_j, 'previous':None}
# #         print(dp_table)
#         for t in range(2,len(sentence)-1):
# #             if(t==2):
# #             print(t-1,"\n", dp_table[t-1])
# #             print(sentence[t])
#             dp_table.append({})
#             transition_probabilities = []
            
#             tags = ['O','B-positive','B-neutral','B-negative','I-positive','I-negative','I-neutral']
#             for tag in tags:
                
#                 for prev_tag in tags:

#                     if((prev_tag,tag) in transition_p.keys()):
                           
#                         a_i_j = transition_p[(prev_tag,tag)] #transition probability from 'START'to tag
# #                         print("Vantage point:",(prev_tag,tag),a_i_j)
                        
#                     else:
# #                         print((prev_tag,tag),"MUHAHAHAHA a1=0")
#                         a_i_j = 0
# #                         pass
                    
#                     if(prev_tag in dp_table[t-1].keys()):
#                         t_p = dp_table[t-1][prev_tag]['p']*a_i_j
#                         transition_probabilities.append(t_p)
# #                 print(transition_probabilities)
#                 max_t_p = max(transition_probabilities)
                
#                 for prev_tag in tags:
#                     if((prev_tag,tag) in transition_p.keys()):
                           
#                         a_i_j = transition_p[(prev_tag,tag)]
#                         print((prev_tag,tag),a_i_j)
                                
#                     else:
# #                         print((prev_tag,tag),"MUHAHAHAHA a2=0")
#                         a_i_j = 0
                    
#                     if prev_tag in dp_table[t-1].keys() and dp_table[t-1][prev_tag]['p']*a_i_j == max_t_p:
#                         if( (sentence[t],tag) in emission_p.keys()):
#                             b_j = emission_p[(sentence[t],tag)] #probability that tag emits word
#                             print((prev_tag,tag),"p=",max_t_p*b_j)
#                         else:
#                             b_j = 0
#                         dp_table[t][tag] = {'p':max_t_p*b_j, 'previous':prev_tag}
                        
# #                         print(sentence[t],tag,"a_i_j=",a_i_j,"b_j=",b_j)
#                         break
#         print("\n",dp_table)
#         for element in dp_table:
#             if element == {}:
#                 index = dp_table.index(element)
#                 del dp_table[index]
# #             print (element)
        
#         #back tracking
#         opt = []
        

#         pmax = max(probabilities['p'] for probabilities in dp_table[-1].values())
#         print (pmax)
#         backward_previous = None
#         for tag, data in dp_table[-1].items():
#             if data["p"] == pmax:
#                 opt.append(tag)
#                 prev_tag = tag
#                 break
        
#         for t in range(len(dp_table) - 2, -1, -1):
#             opt.insert(0, dp_table[t + 1][prev_tag]["previous"])
#             prev_tag = dp_table[t + 1][prev_tag]["previous"]
        
#         print(opt)
#         break
        
# viterbi("C:\\Users\\Lenovo\\Google Drive\\Courses\Term 6\\Machine Learning\\Project\\EN\\train" ,"C:\\Users\\Lenovo\\Google Drive\\Courses\\Term 6\Machine Learning\\Project\\EN\\dev.in")

# %% [markdown]
# Viterbi Algorithm

# %%
import math
def viterbi(train_file_path, test_file_path):
    
    tags = ['O','B-positive','B-neutral','B-negative','I-positive','I-negative','I-neutral']
    emission_p = emission(train_file_path) #{('We', 'O'): 0.003423668687868663, ('were', 'O'): 0.005156127541970878, ('then', 'O'): 0.0006187353050365054,}
    transition_p = estimate_transition_parameters(train_file_path) #{(None, 'O'): 0.47022696929238983, ('O', 'O'): 0.8601188020790363, ('O', None): 0.07623133404834585,}
    sentences = construct_sentences(test_file_path)

    for i in range(len(sentences)):
        sentences[i]=clean_up_test_data(sentences[i],emission_p)
    
    for sentence in sentences:
        print(sentence)
        dp_table = [{},{}]
        for tag in tags:
            if((None,tag) in transition_p.keys()):
                
                a_i_j = transition_p[(None,tag)] #transition probability from 'START'to tag

            else:
                a_i_j = 0
                            
            if( (sentence[1],tag) in emission_p.keys()):
                
                b_j = emission_p[(sentence[1],tag)] #probability that tag emits word
                            
            else:
                b_j = 0
                           
            dp_table[1][tag] = {'p': a_i_j*b_j, 'previous':None}

        for t in range(2,len(sentence)-1):
            dp_table.append({})
            transition_probabilities = {}
            
            tags = ['O','B-positive','B-neutral','B-negative','I-positive','I-negative','I-neutral']
            for tag in tags:
                
                for prev_tag in tags:

                    if((prev_tag,tag) in transition_p.keys()):                           
                        a_i_j = transition_p[(prev_tag,tag)] #transition probability from 'START'to tag
                       
                    else:
                        a_i_j = 0

                    
                    if(prev_tag in dp_table[t-1].keys()):
                        t_p = dp_table[t-1][prev_tag]['p']*a_i_j
                        transition_probabilities[(prev_tag,tag)]=t_p

                max_t_p = max(transition_probabilities.values())
                
                for key in transition_probabilities.keys():
                    if(transition_probabilities[key]==max_t_p):
                        argmax_t_p = key
                
                if((sentence[t],tag) in emission_p.keys()):
                    b_j = emission_p[(sentence[t],tag)] #probability that tag emits word
                else:
                    b_j = 0
                dp_table[t][tag] = {'p':max_t_p*b_j, 'previous':argmax_t_p[0]}

        for element in dp_table:
            if element == {}:
                index = dp_table.index(element)
                del dp_table[index]

        opt = []
        

        pmax = max(probabilities['p'] for probabilities in dp_table[-1].values())
        backward_previous = None
        for tag, data in dp_table[-1].items():
            if data["p"] == pmax:
                opt.append(tag)
                prev_tag = tag
                break
        
        for t in range(len(dp_table) - 2, -1, -1):
            opt.insert(0, dp_table[t + 1][prev_tag]["previous"])
            prev_tag = dp_table[t + 1][prev_tag]["previous"]
        
        print(opt)
        
        
viterbi("C:\\Users\\Lenovo\\Google Drive\\Courses\Term 6\\Machine Learning\\Project\\EN\\train" ,"C:\\Users\\Lenovo\\Google Drive\\Courses\\Term 6\Machine Learning\\Project\\EN\\dev.in")
# Out:
# ['START', 'When', 'I', 'called', 'this', '#UNK#', ',', 'I', "didn't", 'think', 'I', 'would', 'be', 'able', 'to', 'get', 'in', 'at', '#UNK#', ',', 'but', 'I', 'was', 'able', 'to', 'get', 'in', ',', '#UNK#', 'with', 'four', 'other', 'guests', '.', 'STOP']
# ['O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O']
# ['START', 'The', '#UNK#', 'and', '#UNK#', '#UNK#', 'are', 'excellent', '.', 'STOP']
# ['O', 'B-neutral', 'O', 'B-neutral', 'B-neutral', 'O', 'O', 'O']
# ['START', 'My', '#UNK#', 'pizza', 'joint', 'in', 'Seattle', 'STOP']
# ['O', 'B-neutral', 'B-positive', 'O', 'O', 'O']
# ['START', 'Food', '#UNK#', ',', 'its', 'ok', 'but', 'a', 'bit', 'pricey', 'for', 'what', 'you', 'get', 'considering', 'the', 'restaurant', '#UNK#', 'a', '#UNK#', 'place', '.', 'STOP']
# ['B-positive', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'B-neutral', 'O', 'B-neutral', 'B-positive', 'O']
# ['START', 'â€“', '#UNK#', 'away', 'over', 'by', 'the', '#UNK#', '#UNK#', '.', 'STOP']
# ['O', 'B-neutral', 'O', 'O', 'O', 'O', 'B-neutral', 'B-neutral', 'O']
# ['START', 'My', 'mouth', 'felt', 'very', 'dry', '#UNK#', 'and', 'I', 'had', 'that', '#UNK#', '?', '#UNK#', '?', 'taste', '#UNK#', 'in', 'my', '#UNK#', 'after', 'I', 'left', 'the', 'restaurant', '.', 'STOP']
# ['O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'B-neutral', 'O', 'O', 'B-neutral', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'B-positive', 'O']
# ['START', "It's", 'a', 'tiny', 'place', 'so', 'if', 'you', 'get', 'there', 'before', '#UNK#', '#UNK#', 'on', 'a', '#UNK#', '(', '#UNK#', '?', '#UNK#', ')', 'you', 'will', 'find', 'it', '#UNK#', 'to', 'get', 'a', 'table', 'or', 'a', 'seat', 'at', 'the', 'sushi', 'bar', '.', 'STOP']
# ['O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'B-neutral', 'O', 'O', 'B-neutral', 'O', 'B-neutral', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'B-positive', 'O']
# ['START', 'The', 'wine', 'list', 'is', 'wonderful', 'and', 'the', 'food', '#UNK#', 'me', 'of', 'my', '#UNK#', 'trip', 'to', '#UNK#', '.', 'STOP']
# ['O', 'B-positive', 'I-positive', 'O', 'O', 'O', 'O', 'B-positive', 'B-neutral', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'B-neutral', 'O']
# ['START', 'We', 'all', '#UNK#', 'that', '#UNK#', 'is', 'one', 'of', 'the', 'best', 'seafood', 'restaurants', 'in', 'New', 'York', '.', 'STOP']
# ['O', 'O', 'B-neutral', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O']
# ['START', '#UNK#', 'it', '#UNK#', '!', 'STOP']
# ['O', 'O', 'B-neutral', 'O']
# ['START', 'We', 'have', 'since', '#UNK#', 'and', 'also', 'had', 'a', 'great', 'experience', ',', '#UNK#', 'more', 'small', 'plates', 'and', 'a', 'variety', 'of', 'the', '#UNK#', '(', 'cold', 'and', 'good', ')', '.', 'STOP']
# ['O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O']
# ['START', '#UNK#', 'to', '#UNK#', ',', '#UNK#', 'offers', 'a', 'less', '#UNK#', 'bagel', '!', 'STOP']
# ['O', 'O', 'B-neutral', 'O', 'B-neutral', 'O', 'O', 'O', 'B-neutral', 'O', 'O']
# ['START', 'It', 'was', 'so', 'much', 'though', 'that', 'I', 'could', 'barely', '#UNK#', 'but', 'I', 'did', ',', 'since', 'it', 'was', 'delicious', '.', 'STOP']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['START', 'the', 'staff', 'was', 'very', 'nice', 'and', '#UNK#', 'and', '#UNK#', '#UNK#', '.', 'STOP']
# ['O', 'B-positive', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'B-neutral', 'B-neutral', 'O']
# ['START', 
 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['START', 'It', 'is', 'one', 'the', '#UNK#', 'outdoor', 'restaurants', 'I', 'have', 'ever', 'seen', 'in', '#UNK#', 'am', 'from', '#UNK#', 'and', 'this', 'place', '#UNK#', 'the', '#UNK#', 'in', 'my', '#UNK#', '.', 'STOP']
# ['O', 'O', 'O', 'O', 'B-neutral', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'B-neutral', 'O', 'O', 'B-positive', 'B-neutral', 'O', 'B-neutral', 'O', 'O', 'B-neutral', 'O']
# ['START', 'The', 'two', '#UNK#', '#UNK#', 'left', 'quite', 'some', 'time', '#UNK#', 'to', 'open', 'their', 'own', 'place', '.', 'STOP']
# ['O', 'O', 'B-neutral', 'B-neutral', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'B-positive', 'O']
# ['START', 'A', 'cool', 'bar', 'with', 'great', 'food', ',', 'and', 'tons', 'of', 'excellent', '#UNK#', '.', 'STOP']
# ['O', 'O', 'B-positive', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O']
# ['START', 'She', '#UNK#', 'nearby', 'but', 'had', 'never', 'gone', 'to', 'this', 'establishment', '#UNK#', 'that', 'it', 'might', 'be', 'too', '#UNK#', '.', 'STOP']
# ['O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O']
# ['START', 'The', 'menu', 'is', 'very', '#UNK#', '-', 'i', 'think', 'we', '#UNK#', '4', 'or', '5', '#UNK#', '.', 'STOP']
# ['O', 'B-positive', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'B-neutral', 'O']
# ['START', 'In', 'fact', ',', 'it', '#UNK#', 'he', 'is', 'going', 'to', 'go', '#UNK#', 'at', 'any', '#UNK#', '.', 'STOP']
# ['O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'B-neutral', 'O']
# ['START', '#UNK#', 'to', 'be', 'a', 'tasty', 'experience', '!', ')', 'STOP']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['START', 'A', 'little', 'pricey', 'but', 'it', 'really', '#UNK#', 'the', 'spot', 'on', 'a', 'Sunday', '#UNK#', '!', 'STOP']
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'B-positive', 'O', 'O', 'O', 'B-neutral', 'O']
# ['START', 'My', '#UNK#', 'and', 'I', '#UNK#', 'this', 'place', '.', 'STOP']
# ['O', 'B-neutral', 'O', 'O', 'B-neutral', 'O', 'B-positive', 'O']
# ['START', 'I', 'have', 'a', 'but', 'here', '-', 'there', 'was', 'a', '#UNK#', '#UNK#', 'in', 'the', '#UNK#', 'which', 'was', '#UNK#', '.', 'STOP']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'B-neutral', 'O', 'O', 'B-neutral', 'O', 'O', 'B-neutral', 'O']
# ['START', 'The', 'hot', '#UNK#', 'are', 'good', ',', 'yes', ',', 'but', 'the', 'reason', 'to', 'get', 'over', 'here', 'is', 'the', 'fantastic', '#UNK#', '#UNK#', 'sandwich', ',', 'perfect', 'on', 'its', '#UNK#', '#UNK#', '#UNK#', '.', 'STOP']
# ['O', 'B-positive', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'B-neutral', 'I-positive', 'O', 'O', 'O', 'O', 'B-neutral', 'B-neutral', 'B-neutral', 'O']
# ['START', 'It', 'was', '#UNK#', 'he', '#UNK#', 'â€™', 't', 'really', '#UNK#', '.', 'STOP']
# ['O', 'O', 'B-neutral', 'O', 'B-neutral', 'O', 'O', 'O', 'B-neutral', 'O']
# ['START', 'I', 'thought', 'I', 'had', '#UNK#', 'and', 'gone', 'to', '#UNK#', '.', 'STOP']
# ['O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'B-neutral', 'O']
# ['START', 'The', 'food', 'is', 'prepared', 'quickly', 'and', '#UNK#', '.', 'STOP']
# ['O', 'B-positive', 'O', 'O', 'O', 'O', 'B-neutral', 'O']
# ['START', 'This', 'place', 'has', 'the', 'best', 'Chinese', 'style', '#UNK#', '#UNK#', 'in', 'the', 'city', '.', 'STOP']
# ['O', 'B-positive', 'O', 'O', 'O', 'O', 'I-positive', 'B-neutral', 'B-neutral', 'O', 'O', 'O', 'O']
# ['START', 'I', 'recommend', 'it', 'for', 'a', 'night', 'when', 'you', 'want', 'to', '#UNK#', '!', '(', 'it', 'was', 'a', 'bit', 'expensive', ')', 'STOP']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['START', 'We', 'were', 'then', '#UNK#', 'inside', '.', 'STOP']
# ['O', 'O', 'O', 'B-neutral', 'O', 'O']
# ['START', 'I', 'never', 'heard', 'back', 'from', 'anyone', 'more', 'than', 'a', 'month', '#UNK#', '.', 'STOP']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O']
# ['START', 'We', 'got', 'a', 'little', '#UNK#', 'from', 'the', 'sake', 'but', '#UNK#', 'that', 'what', 'Saturday', 'nights', 'with', 'the', '#UNK#', 'are', 'all', 'about', '?', 'STOP']
# ['O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'B-positive', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O']
# ['START', 'A', 'restaurant', 'that', "doesn't", 'try', 'to', 'do', 'anything', 'except', 'serve', 'great', 'food', 'with', 'great', 'service', 'in', 'a', 'pleasant', 'atmosphere', '.', 'STOP']
# ['O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'B-positive', 'O']
# ['START', 'In', '#UNK#', ',', '#UNK#', 'or', '#UNK#', '#UNK#', 'have', '#UNK#', 'less', 'about', 'our', 'being', 'at', 'their', 'establishment', '.', 'STOP']
# ['O', 'B-neutral', 'O', 'B-neutral', 'O', 'B-neutral', 'B-neutral', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['START', 'As', '#UNK#', 'the', '#UNK#', "didn't", '#UNK#', 'in', '#UNK#', ',', 'although', 'it', '#UNK#', '#UNK#', 'on', '#UNK#', 'and', 'selection', '.', 'STOP']
# ['O', 'B-neutral', 'O', 'B-neutral', 'O', 'B-neutral', 'O', 'B-neutral', 'O', 'O', 'O', 'B-neutral', 'B-neutral', 'O', 'B-neutral', 'O', 'I-positive', 'O']
# ['START', 'I', '#UNK#', 'upon', 'this', 'second', 'floor', '#UNK#', 'two', '#UNK#', '#UNK#', 'when', 'I', 'was', 'with', 'two', 'friends', 'in', 'town', 'from', 'L', '.', 'A', '.', 'STOP']
# ['O', 'B-neutral', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'B-neutral', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['START', 'I', 'think', "I've", 'had', 'some', 'the', 'best', 'meals', 'of', 'my', '#UNK#', 'at', '#UNK#', '.', 'STOP']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-negative', 'O', 'O', 'B-neutral', 'O', 'B-neutral', 'O']
# ['START', 'â€“', 'Great', '#UNK#', '#UNK#', '#UNK#', 'spot', '.', 'STOP']
# ['O', 'O', 'B-neutral', 'B-neutral', 'B-neutral', 'B-positive', 'O']
# ['START', "I'll", 'keep', 'this', '#UNK#', '.', 'STOP']
# ['O', 'O', 'O', 'B-neutral', 'O']
# ['START', 'AMAZING', '#UNK#', '#UNK#', '!', '!', '!', 'STOP']
# ['O', 'B-neutral', 'B-neutral', 'O', 'O', 'O']
# ['START', "I'd", 'hate', 'for', '#UNK#', 'to', 'go', 'to', 'Park', '#UNK#', 'and', 'think', 'that', 'this', 'is', 'how', 'all', '#UNK#', '#UNK#', 'restaurants', 'are', 'like', '.', 'STOP']
# ['O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'B-neutral', 'O', 'O', 'O', 'O']
# ['START', 'I', 'got', '#UNK#', 'in', 'my', 'food', '2', 'times', 'of', 'then', '!', 'STOP']
# ['O', 'O', 'B-neutral', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O']
# ['START', 'Great', 'bagels', ',', '#UNK#', 'and', 'a', 'good', 'place', 'to', 'hang', 'out', 'in', '.', 'STOP']
# ['O', 'B-positive', 'O', 'B-neutral', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O']
# ['START', 'My', '#UNK#', 'year', 'old', 'loved', 'it', '.', 'STOP']
# ['O', 'B-neutral', 'O', 'O', 'O', 'O', 'O']
# ['START', "It's", 'very', 'spicy', 'but', 'not', '#UNK#', '.', 'STOP']
# ['O', 'O', 'B-positive', 'O', 'O', 'B-neutral', 'O']
# ['START', 'I', 'had', '#UNK#', '#UNK#', 'with', '#UNK#', '#UNK#', '.', 'STOP']
# ['O', 'O', 'B-neutral', 'B-neutral', 'O', 'B-neutral', 'B-neutral', 'O']
# ['START', '#UNK#', 'staff', 'that', 'actually', '#UNK#', 'you', 'enjoy', 'your', 'meal', 'and', 'the', '#UNK#', "you're", 'with', '.', 'STOP']
# ['O', 'B-positive', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'B-neutral', 'O', 'O', 'O']
# ['START', 'The', 'pizza', 'is', 'overpriced', 'and', 'soggy', '.', 'STOP']
# ['O', 'B-positive', 'O', 'O', 'O', 'O', 'O']
# ['START', 'You', "Can't", 'Go', '#UNK#', '#UNK#', '.', 'STOP']
# ['O', 'O', 'O', 'B-neutral', 'B-neutral', 'O']
# ['START', 'I', '#UNK#', 'the', 'meal', 'with', 'the', '#UNK#', 'dessert', 'of', 'a', '#UNK#', 'and', '#UNK#', '#UNK#', '...', 'yummy', '!', 'STOP']
# ['O', 'B-neutral', 'O', 'B-positive', 'O', 'O', 'B-neutral', 'B-negative', 'O', 'O', 'B-neutral', 'O', 'B-neutral', 'B-neutral', 'O', 'O', 'O']
# ['START', 'But', 'the', 'best', '#UNK#', '#UNK#', 'I', 'ever', 'had', 'is', 'the', 'main', 'thing', '.', 'STOP']
# ['O', 'O', 'O', 'B-neutral', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O']
# ['START', '#UNK#', 'has', '#UNK#', 'food', 'and', 'a', 'nice', 'decor', 'at', 'reasonable', 'prices', '.', 'STOP']
# ['O', 'O', 'B-neutral', 'B-positive', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O']
# ['START', 'I', 'am', '#UNK#', 'to', 'write', 'because', 'I', 'would', 'not', 'want', 'my', '#UNK#', 'of', 'a', 'pizza', 'place', 'to', '#UNK#', '#UNK#', '.', 'STOP']
# ['O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'B-positive', 'B-positive', 'O', 'B-neutral', 'B-neutral', 'O']
# ['START', 'To', 'be', 'completely', '#UNK#', ',', 'the', 'only', '#UNK#', '#UNK#', 'was', 'the', 'food', ',', 'which', 'was', 'above', 'average', ',', 'but', '#UNK#', 'make', 'up', 'for', 'all', 'the', 'other', '#UNK#', 'of', '#UNK#', '.', 'STOP']
# ['O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'B-neutral', 'B-neutral', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'B-neutral', 'O']
# ['START', '#UNK#', 'service', ',', 'food', 'ok', ',', 'pricey', 'STOP']
# ['O', 'B-positive', 'O', 'B-positive', 'O', 'O', 'O']
# ['START', 'The', 'place', 'is', 'so', 'cool', 'and', 'the', 'service', 'is', 'prompt', 'and', '#UNK#', '.', 'STOP']
# ['O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'B-neutral', 'O']
# ['START', 'This', 'is', 'the', 'kind', 'of', 'place', '#UNK#', 'like', 'to', 'take', 'all', 'your', 'friends', 'to', 'and', 'still', 'keep', 'a', '#UNK#', '.', 'STOP']
# ['O', 'O', 'O', 'O', 'O', 'B-positive', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O']
# ['START', 'â€“', 'A', 'group', 'of', '5', 'of', 'us', 'went', 'there', 'for', 'Sunday', 'brunch', 'and', 'sat', 'outside', '.', 'STOP']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['START', 'The', 'food', 'was', 'actually', '#UNK#', '.', 'STOP']
# ['O', 'B-positive', 'O', 'O', 'B-neutral', 'O']
# ['START', 'The', 'service', 'was', 'spectacular', 'as', 'the', 'waiter', '#UNK#', 'everything', 'about', 'the', 'menu', 'and', 'his', '#UNK#', 'were', 'amazing', '!', 'STOP']
# ['O', 'B-positive', 'O', 'O', 'O', 'O', 'B-negative', 'B-neutral', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'B-neutral', 'O', 'O', 'O']
# ['START', '#UNK#', 'guests', 'enjoyed', 'pizza', ',', '#UNK#', '#UNK#', '#UNK#', 'salad', 'and', 'fish', 'and', '#UNK#', '.', 'STOP']
# ['O', 'O', 'O', 'B-positive', 'O', 'B-neutral', 'B-neutral', 'B-neutral', 'I-positive', 'O', 'B-positive', 'O', 'B-neutral', 'O']
# ['START', 'I', 'had', 'the', '#UNK#', 'plate', 'and', 'I', 'enjoyed', 'it', '.', 'STOP']
# ['O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O']
# ['START', 'love', 'the', 'food', '.', 'STOP']
# ['O', 'O', 'B-positive', 'O']
# ['START', 'This', '#UNK#', 'and', 'romantic', '#UNK#', 'is', 'at', 'the', 'top', 'of', 'my', 'Manhattan', 'restaurant', 'list', '.', 'STOP']
# ['O', 'B-neutral', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'I-positive', 'O']
# ['START', 'The', '#UNK#', 'was', 'done', 'to', 'my', '#UNK#', '#UNK#', '(', '#UNK#', '#UNK#', ')', 'and', 'was', 'nice', 'and', '#UNK#', '.', 'STOP']
# ['O', 'B-neutral', 'O', 'O', 'O', 'O', 'B-neutral', 'B-neutral', 'O', 'B-neutral', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O']
# ['START', 'The', 'three', 'of', 'us', '#UNK#', 'in', 'front', 'of', 'her', 'should', 'have', 'been', 'an', '#UNK#', 'of', 'how', 'many', 'of', 'us', 'there', 'were', '.', 'STOP']
# ['O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['START', 'Service', 'was', 'prompt', ',', 'friendly', 'and', 'great', '.', 'STOP']
# ['B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['START', '#UNK#', 'menu', ',', '#UNK#', 'ingredients', ',', '#UNK#', 'fish', ',', '#UNK#', 'rice', '.', 'STOP']
# ['O', 'B-positive', 'O', 'B-neutral', 'B-positive', 'O', 'B-neutral', 'B-positive', 'O', 'B-neutral', 'O', 'O']
# ['START', 'However', ',', 'it', 'is', '#UNK#', 'too', 'good', 'to', 'not', '#UNK#', 'it', '.', 'STOP']
# ['O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O']
# ['START', 'We', 'got', 'most', 'of', 'it', 'back', 'at', 'home', 'with', 'us', '.', 'STOP']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['START', 'This', 'is', 'by', 'far', 'my', 'favorite', 'place', 'in', 'the', 'neighborhood', '.', 'STOP']
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O']
# ['START', 'Will', 'absolutely', 'visit', 'again', '.', 'STOP']
# ['O', 'O', 'O', 'O', 'O']
# ['START', 'really', '#UNK#', 'on', 'your', '#UNK#', '!', 'STOP']
# ['O', 'B-neutral', 'O', 'O', 'B-neutral', 'O']
# ['START', 'There', 'is', 'only', 'one', 'place', 'on', 'the', 'east', '#UNK#', 'that', 'has', 'it', 'all', ',', '#UNK#', 'a', 'lot', 'more', '.', 'STOP']
# ['O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O']
# ['START', 'food', 'was', 'fine', ',', 'with', 'a', 'some', '#UNK#', '#UNK#', '.', 'STOP']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'B-neutral', 'O']
# ['START', 'The', 'food', 'was', 'great', '!', 'STOP']
# ['O', 'B-positive', 'O', 'O', 'O']
# ['START', '#UNK#', 'and', 'friendly', 'service', '.', 'STOP']
# ['O', 'O', 'O', 'B-positive', 'O']
